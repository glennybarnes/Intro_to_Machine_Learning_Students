# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer, Reshape, BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from keras import metrics

import keras
import keras.utils as np_utils

import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
import seaborn as sns

# %%
devices = tf.config.list_physical_devices()
print("\nDevices: ", devices)

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  details = tf.config.experimental.get_device_details(gpus[0])
  print("GPU details: ", details)
# Out:
# Devices:  [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU details:  {'compute_capability': (8, 0), 'device_name': 'NVIDIA A100-SXM4-40GB'}

# %%
# Helper to plot loss
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.legend()
  plt.grid(True)

# %% [markdown]
# # Keras and Tensorflow Optimizations
#
# There are several things that we can do to make our networks a bit better. Unfortunately for much of this there aren't definitive answers for "what is the best choice", so we do have to do some trial and error, but we can use some guidelines to get us started in the right direction.
#
# ## Environment Notes
#
# There were some things that changed since I originally wrote this code with respect to versions and some of the naming schemes in the Keras/Tensorflow libraries. I created a new environment from scratch, and had it install several key packages. The command I used, to make an environment called "blank_tf" was:
#
# ```bash
#  conda create -n blank_tf keras tensorflow pandas seaborn matplotlib scipy numpy scikit-learn
# ```
# This will install those libraries, along with an assortment of their dependencies. If you choose to do something similar, be aware that this environment may lack other libraries that you might need for other stuff, if so, a command of '!pip install <package_name>' will install the package in the current environment.

# %% [markdown]
# ## Load MNIST Data
#
# We can use the MNIST digit dataset for testing, since it is reasonably large.

# %%
# NOTE - you can play with these based on speed of whatever processor you have
# for mine, I'm using a fairly fast one, so we can get some decent results
# Feel free to scale down for practicality
PATIENCE = 10
SMALL_EPOCHS = 15
LARGE_EPOCHS = 200
SMALL_BATCH = 4
LARGE_BATCH = 512
MID_BATCH = 64
XL_BATCH = 4096

HUGE_BATCHES = False
if HUGE_BATCHES:
    multiplier = 50
    SMALL_BATCH = SMALL_BATCH * multiplier
    MID_BATCH = MID_BATCH * multiplier
    LARGE_BATCH = LARGE_BATCH * multiplier
    XL_BATCH = XL_BATCH * multiplier

    SMALL_EPOCHS = SMALL_EPOCHS * 3
    LARGE_EPOCHS = LARGE_EPOCHS * 2
    PATIENCE = PATIENCE * 2

# %%
# Load MNIST dataset
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Normalize the input image so that each pixel value is between 0 and 1.
train_images = train_images / 255.0
test_images = test_images / 255.0

####################################################################################
# Available to test - standardize the data
####
# THOUGHT EXPERIMENT - enable and disable this, observe the results, and see if you can understand why
# Specifically, which change below performs well, and why when this is turned off?
####
# Standardize the data
scaler = StandardScaler()
train_images = scaler.fit_transform(train_images.reshape(-1, 28 * 28))
test_images = scaler.transform(test_images.reshape(-1, 28 * 28))

# Reshape the input image
train_images = train_images.reshape(-1, 28, 28)
test_images = test_images.reshape(-1, 28, 28)
#####################################################################################

print(train_images.shape)

train_labels = np_utils.to_categorical(train_labels)
test_labels = np_utils.to_categorical(test_labels)

model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation="softmax"))

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=SMALL_EPOCHS,
  batch_size=MID_BATCH,
  validation_split=0.2,
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# (60000, 28, 28)
# Epoch 1/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8911 - loss: 0.3846 - val_accuracy: 0.9550 - val_loss: 0.1890
# Epoch 2/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9708 - loss: 0.1145 - val_accuracy: 0.9624 - val_loss: 0.1619
# Epoch 3/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9799 - loss: 0.0800 - val_accuracy: 0.9728 - val_loss: 0.1358
# Epoch 4/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9874 - loss: 0.0441 - val_accuracy: 0.9693 - val_loss: 0.1450
# Epoch 5/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9915 - loss: 0.0357 - val_accuracy: 0.9675 - val_loss: 0.1641
# Epoch 6/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9897 - loss: 0.0372 - val_accuracy: 0.9693 - val_loss: 0.1770
# Epoch 7/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9928 - loss: 0.0257 - val_accuracy: 0.9703 - val_loss: 0.1850
# Epoch 8/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9897 - loss: 0.0482 - val_accuracy: 0.9679 - val_loss: 0.2259
# Epoch 9/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9939 - loss: 0.0268 - val_accuracy: 0.9693 - val_loss: 0.2576
# Epoch 10/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9943 - loss: 0.0208 - val_accuracy: 0.9715 - val_loss: 0.2415
# Epoch 11/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9954 - loss: 0.0197 - val_accuracy: 0.9743 - val_loss: 0.2328
# Epoch 12/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9953 - loss: 0.0133 - val_accuracy: 0.9719 - val_loss: 0.2946
# Epoch 13/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9954 - loss: 0.0160 - val_accuracy: 0.9663 - val_loss: 0.3214
# Epoch 14/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9941 - loss: 0.0260 - val_accuracy: 0.9737 - val_loss: 0.2712
# Epoch 15/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9967 - loss: 0.0129 - val_accuracy: 0.9708 - val_loss: 0.3001
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9650 - loss: 0.3342

# %% [markdown]
# ## Prequel - Saving and Loading Models
#
# As we've seen, models can take a long time to train in many cases. Like with the sklearn models, we can save and load ours as they are trained and reused. This is a pretty integral part of making neural network models usable, so it is pretty easy.
#
# In addition to this we often see models saved in the h5 format, which just saves slightly less stuff along with the model. If we are using models trained elsewhere this format is very common.

# %%
# Save my model
model.save('model_path.keras')
model = keras.models.load_model('model_path.keras')

# %% [markdown]
# ## Network Size
#
# Probably the first question that we will think of when building networks through Tensorflow is "how big should it be"? This is a very big question, and one of those ones without a real answer. We can put some guidelines in place to help us though.
#
# ### What Does the Size Mean?
#
# The size of a neural network is also known as the capacity. We can relate it roughly to the size of our first model, the tree. The larger a network is the higher its capacity to learn. This is similar to a tree, the larger the tree, the more fitted it can become to the training data.
#
# ### What Size to Use?
#
# We can start with a few guidelines to have a reasonably sized neural network. These steps do not ensure an optimal solution, but they'll get us started. There really is not a prescribed method for calculating the optimal network size (beleive me, I've looked), but there are several rules of thumb we can build together to get a rough estimate of a starting point for sizing:
#
# <ul>
# <li> Start with an input layer that is either
#     <ul>
#     <li> The width of the data, if the feature set is relatively small.
#     <li> A reasonably large number if the feature set is large.
#     <li> We don't have a true diving line, but 512 is a reasonable value to try for an upper end, at least at first.
#     </ul>
# <li> Add 1 or 2 hidden layers of the same size and observe the results. We want to keep the model smaller if making it larger doesn't improve things, so first we shoudl see how good of a job a small model does. If the data is very large, skipping past the 1 layer step may save some time since we can predict that we can do better with a larger model in advance.
# <li> Increase layers of the same size until we get some overfitting and the training loss flattens. We want to reach the point where the model is getting to be excellent at predicting the training data. This is something we can see in the plot by noticing that the validation loss flatlines or starts to get worse. The training loss flattening is an indication that the model is not getting any better at learning the training data; we can use early stopping with a loose patience setting on training loss and lots of epochs to find this.
# <li> Add regularization steps to cut down that overfitting. We can try regularization and dropouts to cut down on that overfitting. We probably want to try a few options, parameters, and combinations here, there's not really a way to know in advance which regularization will work best on our data.
# <li> Do a test of "funneling" the layer size, potentially adding more layers. The traditional configuration of layers is to gradually decrease the size from the input layer towards the output layer. There is open debate on if this is better than having layers that are all the same size. We can play with this a little to see if results improve or not.
# <li> Use pruning. Much like a tree we can prune back a model to fight overfitting.
# </ul>
#
# ### Height vs Width
#
# Another begged question is should we make networks wider (more neurons) or deeper (more layers)? To that effect, we can also think about what happens as layers are added. Each layer allows the network to learn a different representation of the data, and if we flash back to the simple logistic regression and XOR examples, each layer allows the model to capture relationships that are more complex:
# <ul>
# <li> No hidden layers - linear relationships only.
# <li> 1 or more hidden layers - nonlinear relationships, of increasing complexity.
# </ul>
#
# So the number of layers in our model directly relates to the complexity of relationships that we can capture. This doesn't directly mean that more layers are better, but it generally means that we want the number of layers to mirror the "complexity" of the data, though complexity is a term with no exact definition or metric here. Once again, there's no universal answer on the balance between width of layers and number of layers, but the general evidence leans towards more layers. There are several reasons for this, none of them definitive, but taken as a whole they add up to a strong case:
#
# <ul>
# <li> Ability to learn different representation of the data - this will be more clear next time when we start to look at some image specific neural networks, but one of the cool features of neural networks is that at each layer the network "sees" a different representation of the data, as it goes through each round of transformations. This has the effect of allowing it to identify different features at each layer, and use those features to make more and more accurate predictions. We'll examine this more soon.
# <li> Avoiding overfitting - extremely wide neural networks tend towards overfitting the training data and not generalizing as well to new data.
# <li> Ability to add interim steps - with a multi layer network we can add multiple steps such as regularization or dropouts, again to fight overfitting.
# <li> Automatic feature selection - deep neural networks will automatically perform a type of feature selection as the least important features are minimized in their importance. This is an emerging area of research - some people have argued that well designed neural networks can remove the need for feature selection, and neural networks are being created to be feature selection tools. We can see this illustrated most clearly with images again, we feed a network an entire image, and get a prediction. Note that this isn't a total rejection of feature selection for neural networks, improving the feature set will impact neural network models just as it will for ordinary models; with neural networks we just have the potential for the network to "cover for mistakes" in the features. This is more dramatic as data size and network size increase.
# <li> Results - deep learning has become a common term recently for a reason, due to the success of deep neural networks with many layers. Most of the cool stuff that we see coming from AI such as image recognition, translation, and self navigating robots are the result of deep learning networks. In practice these networks have tended to outperform shallower ones, especially in more complex tasks.
# </ul>
#
# ### Overfitting and Underfitting
#
# Why not make a model that is both very wide and very deep? This will tend to overfit as it can "memorize" the training data. With large datasets we do see very large models in some cases, since the more data we have, the more fitting we can handle. With large datasets and huge models, the training time can potentially explode, so we have to be careful. This is similar to what we saw with unlimited size in trees, we can eventually create a model large enough to memorize the training data. On the whole, the model capacity can be thought of similarly to the size of a tree. If we have large amounts of complex data, we want a model that has a very high capacity, as the relationships are complicated and we have enough data to mitigate overfitting. If we have smaller or more simple data, we want a smaller model, as a large one will overfit our data.
#
# Finding the "optimal" size is still somewhat of an art, combined with patience for trial and error. <b>The easiest starting point is probably to create a model that can potentially overfit, though not comically large, then use some regularization techniques and early stopping to find the optimal fit.</b> We should also note that it is possible and reasonable that models of different sizes and configurations tend to converge on similar levels of performace. These neural networks are extremely flexible in how they learn during the training process, so they can "learn around" some degree of design decisions in a way that is more dramatic than our previous models.

# %%
# Model
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(Dense(784, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(784, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=LARGE_EPOCHS,
  validation_split=0.2,
  batch_size=MID_BATCH,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8799 - loss: 0.4269 - val_accuracy: 0.9533 - val_loss: 0.1717
# Epoch 2/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9597 - loss: 0.1452 - val_accuracy: 0.9597 - val_loss: 0.1801
# Epoch 3/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9677 - loss: 0.1221 - val_accuracy: 0.9687 - val_loss: 0.1214
# Epoch 4/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9768 - loss: 0.0817 - val_accuracy: 0.9652 - val_loss: 0.1454
# Epoch 5/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9787 - loss: 0.0730 - val_accuracy: 0.9671 - val_loss: 0.1655
# Epoch 6/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9806 - loss: 0.0725 - val_accuracy: 0.9692 - val_loss: 0.1368
# Epoch 7/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9812 - loss: 0.0694 - val_accuracy: 0.9673 - val_loss: 0.1520
# Epoch 8/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9839 - loss: 0.0552 - val_accuracy: 0.9723 - val_loss: 0.1426
# Epoch 9/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9858 - loss: 0.0527 - val_accuracy: 0.9724 - val_loss: 0.1576
# Epoch 10/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9837 - loss: 0.0588 - val_accuracy: 0.9717 - val_loss: 0.1619
# Epoch 11/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9855 - loss: 0.0533 - val_accuracy: 0.9750 - val_loss: 0.1416
# Epoch 12/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9892 - loss: 0.0423 - val_accuracy: 0.9737 - val_loss: 0.1733
# Epoch 13/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9881 - loss: 0.0514 - val_accuracy: 0.9722 - val_loss: 0.2047
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9667 - loss: 0.1310

# %%
# Bigger Model
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=LARGE_EPOCHS,
  validation_split=0.2,
  batch_size=MID_BATCH,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.8411 - loss: 0.5192 - val_accuracy: 0.9541 - val_loss: 0.1579
# Epoch 2/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9510 - loss: 0.1674 - val_accuracy: 0.9502 - val_loss: 0.1783
# Epoch 3/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9604 - loss: 0.1432 - val_accuracy: 0.9654 - val_loss: 0.1212
# Epoch 4/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9697 - loss: 0.1038 - val_accuracy: 0.9653 - val_loss: 0.1259
# Epoch 5/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9712 - loss: 0.0979 - val_accuracy: 0.9688 - val_loss: 0.1240
# Epoch 6/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9779 - loss: 0.0808 - val_accuracy: 0.9713 - val_loss: 0.1212
# Epoch 7/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9792 - loss: 0.0774 - val_accuracy: 0.9704 - val_loss: 0.1249
# Epoch 8/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9798 - loss: 0.0688 - val_accuracy: 0.9707 - val_loss: 0.1352
# Epoch 9/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9832 - loss: 0.0621 - val_accuracy: 0.9698 - val_loss: 0.1330
# Epoch 10/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9810 - loss: 0.0675 - val_accuracy: 0.9734 - val_loss: 0.1204
# Epoch 11/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9844 - loss: 0.0577 - val_accuracy: 0.9743 - val_loss: 0.1336
# Epoch 12/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9837 - loss: 0.0618 - val_accuracy: 0.9750 - val_loss: 0.1294
# Epoch 13/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9856 - loss: 0.0600 - val_accuracy: 0.9770 - val_loss: 0.1430
# Epoch 14/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9861 - loss: 0.0573 - val_accuracy: 0.9746 - val_loss: 0.1351
# Epoch 15/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9858 - loss: 0.0577 - val_accuracy: 0.9739 - val_loss: 0.1337
# Epoch 16/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9880 - loss: 0.0495 - val_accuracy: 0.9717 - val_loss: 0.1696
# Epoch 17/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0467 - val_accuracy: 0.9748 - val_loss: 0.1458
# Epoch 18/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9882 - loss: 0.0532 - val_accuracy: 0.9738 - val_loss: 0.1894
# Epoch 19/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9888 - loss: 0.0455 - val_accuracy: 0.9724 - val_loss: 0.1851
# Epoch 20/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9871 - loss: 0.0578 - val_accuracy: 0.9743 - val_loss: 0.1576
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9683 - loss: 0.1412

# %%
# Tapered Model
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(350, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(200, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=LARGE_EPOCHS,
  validation_split=0.2,
  batch_size=MID_BATCH,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.7627 - loss: 0.7529 - val_accuracy: 0.9532 - val_loss: 0.1652
# Epoch 2/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9401 - loss: 0.2219 - val_accuracy: 0.9628 - val_loss: 0.1414
# Epoch 3/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9565 - loss: 0.1656 - val_accuracy: 0.9636 - val_loss: 0.1321
# Epoch 4/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9658 - loss: 0.1326 - val_accuracy: 0.9667 - val_loss: 0.1306
# Epoch 5/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9695 - loss: 0.1165 - val_accuracy: 0.9712 - val_loss: 0.1175
# Epoch 6/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9741 - loss: 0.0961 - val_accuracy: 0.9691 - val_loss: 0.1258
# Epoch 7/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9744 - loss: 0.0916 - val_accuracy: 0.9722 - val_loss: 0.1155
# Epoch 8/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9798 - loss: 0.0785 - val_accuracy: 0.9702 - val_loss: 0.1103
# Epoch 9/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9797 - loss: 0.0749 - val_accuracy: 0.9704 - val_loss: 0.1227
# Epoch 10/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9804 - loss: 0.0710 - val_accuracy: 0.9723 - val_loss: 0.1206
# Epoch 11/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9836 - loss: 0.0626 - val_accuracy: 0.9731 - val_loss: 0.1141
# Epoch 12/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9834 - loss: 0.0621 - val_accuracy: 0.9750 - val_loss: 0.1393
# Epoch 13/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9850 - loss: 0.0602 - val_accuracy: 0.9744 - val_loss: 0.1397
# Epoch 14/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9855 - loss: 0.0533 - val_accuracy: 0.9749 - val_loss: 0.1284
# Epoch 15/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9859 - loss: 0.0492 - val_accuracy: 0.9743 - val_loss: 0.1369
# Epoch 16/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9882 - loss: 0.0473 - val_accuracy: 0.9748 - val_loss: 0.1546
# Epoch 17/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9882 - loss: 0.0442 - val_accuracy: 0.9737 - val_loss: 0.1426
# Epoch 18/200
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9865 - loss: 0.0528 - val_accuracy: 0.9762 - val_loss: 0.1397
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9664 - loss: 0.1257

# %% [markdown]
# ## Epochs and Batch Sizes
#
# ![Batch Sizes](images/iterations_epoch.webp "Batch Sizes")
#
# ### Epochs
#
# Each epoch is a run through all of the training data. Epochs are simple, we can set a large number and use early stopping to cut things off when we've reached the best result.
#
# ### Batch Sizes
#
# Batch size determines how many records are processed before the gradients are updated - i.e. the number of records between one forward and backwards pass. The batch sizes are a matter of very open debate for the optimal solution. At the high end, batch sizes are limited by what can fit in memory. When dealing with very large data this may matter as a batch that is a small fraction of the data may be a massive absolute size. At the lower end using smaller batches gives the same effect as it does when we looked at regular gradient descent - the gradients become less stable as we are relying on a smaller number of records. In reading more about batch sizes I want to update my recommendation to be even smaller than the 50 to 150 I suggested before, down to less than 100, even as small as into the single digits. There is research that smaller batch sizes tend to produce models that generalize better than ones with larger batches.
#
# Larger batch sizes do tend to be processed more quickly, sometimes substantially so, as the hardware is better able to be "saturated" with data to process. In big data scenarios, this can matter. One thing that you see in practice is that the GPUs (or similar) that are used to train neural networks have a certain amount of memory, and the batch size is limited by that memory. When doing something that involves large images or video, or similar, this can be a real area for concern. For us, these constraints won't really come up, but it's good to be aware of them.
#
# Dont' stress too much on batch size, this is really something that needs to be grid searched to find a great answer and in scenarios where it actually matters, is largely influenced by the hardware that is available.

# %%
# Big Batch
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(350, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=LARGE_EPOCHS,
  batch_size=LARGE_BATCH,
  validation_split=0.2,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - accuracy: 0.7776 - loss: 0.7201 - val_accuracy: 0.9550 - val_loss: 0.1614
# Epoch 2/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9494 - loss: 0.1622 - val_accuracy: 0.9636 - val_loss: 0.1282
# Epoch 3/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9659 - loss: 0.1107 - val_accuracy: 0.9670 - val_loss: 0.1133
# Epoch 4/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9747 - loss: 0.0823 - val_accuracy: 0.9704 - val_loss: 0.1032
# Epoch 5/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9792 - loss: 0.0671 - val_accuracy: 0.9712 - val_loss: 0.1063
# Epoch 6/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9828 - loss: 0.0553 - val_accuracy: 0.9724 - val_loss: 0.0977
# Epoch 7/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0435 - val_accuracy: 0.9748 - val_loss: 0.1002
# Epoch 8/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0344 - val_accuracy: 0.9750 - val_loss: 0.0973
# Epoch 9/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9897 - loss: 0.0331 - val_accuracy: 0.9758 - val_loss: 0.1006
# Epoch 10/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9917 - loss: 0.0271 - val_accuracy: 0.9757 - val_loss: 0.1084
# Epoch 11/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0269 - val_accuracy: 0.9758 - val_loss: 0.1082
# Epoch 12/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0256 - val_accuracy: 0.9780 - val_loss: 0.0976
# Epoch 13/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9934 - loss: 0.0199 - val_accuracy: 0.9766 - val_loss: 0.1082
# Epoch 14/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9933 - loss: 0.0196 - val_accuracy: 0.9783 - val_loss: 0.1023
# Epoch 15/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9942 - loss: 0.0190 - val_accuracy: 0.9764 - val_loss: 0.1058
# Epoch 16/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9943 - loss: 0.0180 - val_accuracy: 0.9775 - val_loss: 0.1139
# Epoch 17/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9941 - loss: 0.0175 - val_accuracy: 0.9761 - val_loss: 0.1199
# Epoch 18/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9946 - loss: 0.0162 - val_accuracy: 0.9772 - val_loss: 0.1178
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9718 - loss: 0.1122

# %%
# Small Batch
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(350, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

# Note: Batch size of 2 is good to test
# But it can take a VERY long time, be aggressive with the early stopping
train_log = model.fit(
  train_images,
  train_labels,
  epochs=SMALL_EPOCHS,
  batch_size=SMALL_BATCH,
  validation_split=0.2,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8643 - loss: 0.5973 - val_accuracy: 0.9289 - val_loss: 0.2764
# Epoch 2/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9225 - loss: 0.3282 - val_accuracy: 0.9503 - val_loss: 0.2231
# Epoch 3/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9377 - loss: 0.2948 - val_accuracy: 0.9507 - val_loss: 0.2290
# Epoch 4/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9398 - loss: 0.2980 - val_accuracy: 0.9551 - val_loss: 0.2276
# Epoch 5/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9413 - loss: 0.3017 - val_accuracy: 0.9519 - val_loss: 0.2921
# Epoch 6/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9445 - loss: 0.2887 - val_accuracy: 0.9537 - val_loss: 0.2581
# Epoch 7/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9434 - loss: 0.3289 - val_accuracy: 0.9528 - val_loss: 0.2420
# Epoch 8/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9475 - loss: 0.3319 - val_accuracy: 0.9510 - val_loss: 0.2978
# Epoch 9/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9470 - loss: 0.3479 - val_accuracy: 0.9553 - val_loss: 0.3811
# Epoch 10/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9479 - loss: 0.4256 - val_accuracy: 0.9576 - val_loss: 0.2763
# Epoch 11/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9468 - loss: 0.3717 - val_accuracy: 0.9504 - val_loss: 0.2916
# Epoch 12/15
# 12000/12000 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9480 - loss: 0.3408 - val_accuracy: 0.9559 - val_loss: 0.3786
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9445 - loss: 0.2680

# %% [markdown]
# ## Optimizer
#
# Of all options the optimizer is the one we will care about the least. Each different optimizer is a different algorithm for doing the gradient descent. The optimizers have different results with respect to speed, memory usage, computational expense, and likelyhood to get stuck in a local minima. The optimizer is similar to some of the options we saw with logistic regression - there were several solver options for that model, each of which performed the gradient descent process with a slightly different set of calculations. Optimizers tend to manipulate the learning rate, attempting to narrow in on the optimum weights in fewer epochs and thus fewer calculations.
#
# ![Optimizers](images/optimizers.gif "Optimizers")
#
# <b>Note:</b> this animation doesn't have Adam, which is unfortumate, but it was the most clear one I could find. The different optimizers are all trying to find the same minimum, and in most cases they all do, but they take differnt paths to get there, over a different number of steps.
#
# Adam is a good compromise between all factors and is very commonly used. We'll just use this for our work. One other common one is RMSprop, if you're feeling spicy, give that a try and see if there are any imporvements. These optimizers don't change the model we are making (outside of edge cases, like getting stuck in a minima), they change the process of finding that model. The biggest impact of the optimizer is on the speed of the training process, and in turn the ability to experiment with different models. This is more of a concern as the data gets larger, as small improvements on each individual gradient descent step can add up to large improvements in the overall training time.

# %%
optimizer_1 = tf.keras.optimizers.Adam()
optimizer_2 = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Activation
#
# Activation functions are the key to adding non-linearity to the network allowing it to learn complex and non-linear relationships in the data. We've used ReLU as the default and that is a solid choice in most cases. ReLU has one issue, the dying ReLU problem. This can happen when we get inputs to the activation function fall in the negative area. In short there can be neurons that "die" and never get updated again because the value becomes 0 and stays 0. These dead neurons are a problem as they now aren't contributing to the learning.
#
# ![ReLU](images/relu.jpeg "ReLU")
#
# To combat the dying ReLU problem there are a couple of other activation functions that avoid that issue - Leaky ReLU and ELU. Each one changes the negative values to something other than 0 - Leaky ReLU uses a slight linear gradient, ELU uses an exponential function for a similar, but curved, slight gradient. These ReLU variants are a good choice, and probably the 'best' overall activation functions for most scenarios. One some datasets will be impacted by the dying ReLU problem.
#
# These activation function also have an impact on the speed of training. The ReLU function is very fast to calculate, and the Leaky ReLU and ELU functions are a bit slower. Other activation functions may be even more expensive. Will this matter? As with many things, it depends. For the small examples we are using, it probably won't matter much. On very large applications, we may need to consider the ability to train models more quickly, and try more models vs. the improved fit of another activation function.
#
# #### Activation Function Guidelines
#
# We can write a few rules of thumb to guide us in deciding on activation functions. On the whole, the choice is like a hyperparameter choice, and we want to choose whichever is the best for our data. Some of the guidelines are:
# <ul>
# <li> The output layer should have an activation function that matches the type of problem we are solving.
#     <ul>
#     <li> <b>Regression:</b> Linear activation function.
#     <li> <b>Binary Classification:</b> Sigmoid activation function.
#     <li> <b>Multiclass Classification:</b> Softmax activation function.
#     </ul>
# <li> Depending on the type of network/problem, our hidden layers default to different activation functions:
#     <ul>
#     <li> <b>Deep Neural Networks:</b> ReLU activation functions.
#     <li> <b>Convolutional Neural Networks: (Images)</b> ReLU activation functions.
#     <li> <b>Recurrent Neural Networks:(Seqential, Time Series)</b> Tanh activation function.
#     </ul>
# </ul>
#
# There are more activation functions, and others are being developed somewhat regularly. If in doubt, just use a ReLU variant.

# %%
# Take a leak
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(Dense(500, activation='leaky_relu'))
model.add(Dropout(0.2))
model.add(Dense(350, activation='leaky_relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer=optimizer_2, loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=SMALL_EPOCHS,
  batch_size=MID_BATCH,
  validation_split=0.2,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8741 - loss: 0.4412 - val_accuracy: 0.9542 - val_loss: 0.1700
# Epoch 2/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9492 - loss: 0.1800 - val_accuracy: 0.9617 - val_loss: 0.1484
# Epoch 3/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9609 - loss: 0.1381 - val_accuracy: 0.9617 - val_loss: 0.1581
# Epoch 4/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9666 - loss: 0.1262 - val_accuracy: 0.9684 - val_loss: 0.1364
# Epoch 5/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9686 - loss: 0.1159 - val_accuracy: 0.9670 - val_loss: 0.1551
# Epoch 6/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9716 - loss: 0.1075 - val_accuracy: 0.9691 - val_loss: 0.1479
# Epoch 7/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9729 - loss: 0.0988 - val_accuracy: 0.9697 - val_loss: 0.1489
# Epoch 8/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9757 - loss: 0.0891 - val_accuracy: 0.9703 - val_loss: 0.1429
# Epoch 9/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9757 - loss: 0.0930 - val_accuracy: 0.9716 - val_loss: 0.1540
# Epoch 10/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9761 - loss: 0.0976 - val_accuracy: 0.9722 - val_loss: 0.1518
# Epoch 11/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9777 - loss: 0.0933 - val_accuracy: 0.9719 - val_loss: 0.1629
# Epoch 12/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9782 - loss: 0.0903 - val_accuracy: 0.9703 - val_loss: 0.1692
# Epoch 13/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9789 - loss: 0.0883 - val_accuracy: 0.9715 - val_loss: 0.1739
# Epoch 14/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9796 - loss: 0.0800 - val_accuracy: 0.9718 - val_loss: 0.1721
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9617 - loss: 0.1653

# %% [markdown]
# ## Batch Normalization
#
# Batch normalization is a technique that is used to normalize the inputs of each layer, so that the network can learn more quickly and with more stability. This is a technique that is used to help with the vanishing gradient problem, which is a problem that can occur when the gradients become very small and the network stops learning. This is a common problem with deep networks, and batch normalization is a common solution.
#
# Using batch normalization can have a few effects on the network:
# <ul>
# <li> Faster training - the network can learn more quickly with batch normalization.
# <li> More stable training - the network is less likely to get stuck in a local minima.
# <li> Regularization - batch normalization can act as a form of regularization, helping to prevent overfitting.
# </ul>
#
# Batch normalization is a good choice for many networks, and we see it used very commonly in practice. It is unlikely to make things worse. Implementing batch normalization is as simple as adding a layer to the network. In most cases we can add it after the activation function, meaning after a dense layer here. It can be done at other points, such as before the activation layer, if it is separated from the dense layer - this is more of a fine-tuning concern.

# %%
# with sigmoid
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add( BatchNormalization())
model.add(Dense(500, activation='sigmoid'))
model.add(BatchNormalization())
model.add(Dense(350, activation='sigmoid'))
model.add(BatchNormalization())
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=LARGE_EPOCHS,
  batch_size=LARGE_BATCH,
  validation_split=0.2,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8172 - loss: 0.6186 - val_accuracy: 0.7398 - val_loss: 1.2066
# Epoch 2/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9393 - loss: 0.2063 - val_accuracy: 0.8566 - val_loss: 0.5856
# Epoch 3/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9594 - loss: 0.1445 - val_accuracy: 0.8816 - val_loss: 0.3663
# Epoch 4/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9698 - loss: 0.1051 - val_accuracy: 0.9063 - val_loss: 0.2695
# Epoch 5/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9792 - loss: 0.0741 - val_accuracy: 0.9193 - val_loss: 0.2321
# Epoch 6/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9857 - loss: 0.0525 - val_accuracy: 0.9621 - val_loss: 0.1330
# Epoch 7/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0367 - val_accuracy: 0.9669 - val_loss: 0.1205
# Epoch 8/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9938 - loss: 0.0260 - val_accuracy: 0.9646 - val_loss: 0.1272
# Epoch 9/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9951 - loss: 0.0199 - val_accuracy: 0.9716 - val_loss: 0.1071
# Epoch 10/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9976 - loss: 0.0132 - val_accuracy: 0.9729 - val_loss: 0.1046
# Epoch 11/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0103 - val_accuracy: 0.9737 - val_loss: 0.1074
# Epoch 12/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0069 - val_accuracy: 0.9747 - val_loss: 0.1066
# Epoch 13/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0056 - val_accuracy: 0.9750 - val_loss: 0.1079
# Epoch 14/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.9757 - val_loss: 0.1128
# Epoch 15/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0083 - val_accuracy: 0.9743 - val_loss: 0.1128
# Epoch 16/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0061 - val_accuracy: 0.9765 - val_loss: 0.1054
# Epoch 17/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0042 - val_accuracy: 0.9744 - val_loss: 0.1120
# Epoch 18/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0027 - val_accuracy: 0.9766 - val_loss: 0.1102
# Epoch 19/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9775 - val_loss: 0.1056
# Epoch 20/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.5332e-04 - val_accuracy: 0.9781 - val_loss: 0.1076
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9687 - loss: 0.1194

# %%
# With ReLU
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(500, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(350, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=LARGE_EPOCHS,
  batch_size=LARGE_BATCH,
  validation_split=0.2,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8351 - loss: 0.5523 - val_accuracy: 0.9514 - val_loss: 0.1907
# Epoch 2/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9751 - loss: 0.0868 - val_accuracy: 0.9654 - val_loss: 0.1341
# Epoch 3/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0431 - val_accuracy: 0.9681 - val_loss: 0.1379
# Epoch 4/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9944 - loss: 0.0263 - val_accuracy: 0.9718 - val_loss: 0.1448
# Epoch 5/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9962 - loss: 0.0189 - val_accuracy: 0.9724 - val_loss: 0.1770
# Epoch 6/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9982 - loss: 0.0108 - val_accuracy: 0.9749 - val_loss: 0.1895
# Epoch 7/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0066 - val_accuracy: 0.9747 - val_loss: 0.2067
# Epoch 8/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0043 - val_accuracy: 0.9767 - val_loss: 0.2037
# Epoch 9/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0022 - val_accuracy: 0.9758 - val_loss: 0.2296
# Epoch 10/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0019 - val_accuracy: 0.9764 - val_loss: 0.2656
# Epoch 11/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0013 - val_accuracy: 0.9775 - val_loss: 0.2856
# Epoch 12/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.2485e-04 - val_accuracy: 0.9778 - val_loss: 0.2991
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9631 - loss: 0.1428

# %% [markdown]
# ### Add Regularization

# %%
# With regularization
model = keras.Sequential()
model.add(InputLayer(shape=(28, 28)))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(500, activation='relu',kernel_regularizer="l2"))
model.add(BatchNormalization())
model.add(Dense(350, activation='relu',kernel_regularizer="l2"))
model.add(BatchNormalization())
model.add(Dense(10, activation="softmax"))

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the digit classification model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

train_log = model.fit(
  train_images,
  train_labels,
  epochs=LARGE_EPOCHS,
  batch_size=LARGE_BATCH,
  validation_split=0.2,
  callbacks=[callback]
)
model.evaluate(test_images, test_labels)
plot_loss(train_log)
# Out:
# Epoch 1/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8386 - loss: 7.7586 - val_accuracy: 0.9350 - val_loss: 2.2717
# Epoch 2/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9611 - loss: 1.1655 - val_accuracy: 0.8533 - val_loss: 0.9272
# Epoch 3/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9651 - loss: 0.3903 - val_accuracy: 0.9441 - val_loss: 0.4683
# Epoch 4/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9660 - loss: 0.2918 - val_accuracy: 0.9546 - val_loss: 0.3421
# Epoch 5/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9665 - loss: 0.2820 - val_accuracy: 0.9607 - val_loss: 0.3011
# Epoch 6/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9721 - loss: 0.2557 - val_accuracy: 0.9598 - val_loss: 0.3276
# Epoch 7/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9724 - loss: 0.2528 - val_accuracy: 0.9630 - val_loss: 0.2876
# Epoch 8/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9711 - loss: 0.2536 - val_accuracy: 0.9673 - val_loss: 0.3015
# Epoch 9/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9731 - loss: 0
200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9887 - loss: 0.1082 - val_accuracy: 0.9726 - val_loss: 0.1757
# Epoch 81/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9869 - loss: 0.1117 - val_accuracy: 0.9722 - val_loss: 0.1710
# Epoch 82/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9878 - loss: 0.1073 - val_accuracy: 0.9698 - val_loss: 0.1939
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9697 - loss: 0.1917

# %% [markdown]
# ## Initialization
#
# The initialization provides the starting point for all the weights and bias values that we start out with. We initially started with random values in the scratch network - this is generally fine, but we can sometimes do better. One specific case where we can do better is when we have data that is highly imbalanced. This is a common problem in things such as fraud detection, where we have a very small number of fraud cases, and a very large number of non-fraud cases. Seeding the model with an "expectation" of the bias values can help the model learn faster and converge on an answer more quickly. In cases where we have a lot of data, this can be a big deal. In cases where we may have local minima in the loss curve, this can be significant - the more "ground" the gradient descent covers, the greater the odds it encounters a local minima that might be a trap. With imbalanced data, we expect that the model will need to cover a lot of that ground, so starting off with a better bias value can help.
#
# ### Imbalanced Weighting
#
# One application where initialization can help significantly is when dealing with imbalanced data. In this example of credit card fraud (real data that has been put through PCA), very, very few transactions are fraudulent. So we have a very imbalanced target value - the class variable.

# %%
file = tf.keras.utils
raw_df = pd.read_csv('https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv')
raw_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Count the Target Outcomes
#
# Credit card fraud is relatively rare, at least in view of the total number of transactions. We can count up the target values to see exactly what the expected skew is.

# %%
# Bincount will count the number in each category
neg, pos = np.bincount(raw_df['Class'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 284807
#     Positive: 492 (0.17% of total)

# %% [markdown]
# ### We Have an Imbalance
#
# A big one.

# %%
# pop just removes a column. The equivalent of how we normally drop.
# the TF docs commonly use this, so I've left it as is.
cleaned_df = raw_df.copy()
# You don't want the `Time` column.
cleaned_df.pop('Time')
# Out:
# 0              0.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              2.0
#             ...
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Time, Length: 284807, dtype: float64

# %%
# Use a utility from sklearn to split and shuffle your dataset.
train_df, test_df = train_test_split(cleaned_df, test_size=0.2)

# Form np arrays of labels and features.
train_labels = np.array(train_df.pop('Class'))
test_labels = np.array(test_df.pop('Class'))

train_features = np.array(train_df)
test_features = np.array(test_df)

# %%
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)
test_features = scaler.transform(test_features)

#train_features = np.clip(train_features, -5, 5)
#test_features = np.clip(test_features, -5, 5)

print('Training features shape:', train_features.shape)
print('Training labels shape:', train_labels.shape)
print('Test features shape:', test_features.shape)
print('Test labels shape:', test_labels.shape)
# Out:
# Training features shape: (227845, 29)
# Training labels shape: (227845,)
# Test features shape: (56962, 29)
# Test labels shape: (56962,)

# %% [markdown]
# #### Baseline Model
#
# First, we'll set a baseline model with the default settings. I'm going to make this the same structure as the bias model, so we can assess the impact.

# %%
METRICS = [
      #keras.metrics.TruePositives(name='tp'),
      #keras.metrics.FalsePositives(name='fp'),
      #keras.metrics.TrueNegatives(name='tn'),
      #keras.metrics.FalseNegatives(name='fn'),
      #keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

fraud_width_1 = 16
fraud_width_2 = 16
fraud_width_3 = 16

# %%
# Baseline model
model = keras.Sequential()
model.add(InputLayer(shape=(train_features.shape[1],)))
model.add(BatchNormalization())
model.add(Dense(fraud_width_1, activation='leaky_relu', kernel_regularizer="l2"))
model.add(BatchNormalization())
model.add(Dense(fraud_width_1, activation='leaky_relu', kernel_regularizer="l2"))
model.add(BatchNormalization())
model.add(Dense(fraud_width_3, activation='leaky_relu', kernel_regularizer="l2"))
model.add(BatchNormalization())
model.add(Dense(1, activation='sigmoid'))
model.summary()

model.compile(optimizer="adam",loss="binary_crossentropy",metrics=METRICS)

#Fit
train_log = model.fit(
  train_features,
  train_labels,
  epochs=SMALL_EPOCHS*3,
  batch_size=MID_BATCH,
  validation_split=0.2,
  callbacks=[callback]
)
model.evaluate(test_features, test_labels)
plot_loss(train_log)
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization_9                │ (None, 29)                  │             116 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 16)                  │             480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_37 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,349 (5.27 KB)
#  Trainable params: 1,195 (4.67 KB)
#  Non-trainable params: 154 (616.00 B)
# Epoch 1/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - auc: 0.7905 - loss: 0.3365 - prc: 0.1100 - precision: 0.0275 - recall: 0.3824 - val_auc: 0.9374 - val_loss: 0.0063 - val_prc: 0.7474 - val_precision: 0.8750 - val_recall: 0.6125
# Epoch 2/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9015 - loss: 0.0067 - prc: 0.6399 - precision: 0.8117 - recall: 0.5484 - val_auc: 0.9547 - val_loss: 0.0078 - val_prc: 0.7726 - val_precision: 0.8214 - val_recall: 0.8625
# Epoch 3/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9031 - loss: 0.0069 - prc: 0.6139 - precision: 0.7765 - recall: 0.5735 - val_auc: 0.9436 - val_loss: 0.0080 - val_prc: 0.7716 - val_precision: 0.8590 - val_recall: 0.8375
# Epoch 4/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9101 - loss: 0.0061 - prc: 0.6002 - precision: 0.7505 - recall: 0.5812 - val_auc: 0.9556 - val_loss: 0.0081 - val_prc: 0.7350 - val_precision: 0.7303 - val_recall: 0.8125
# Epoch 5/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9033 - loss: 0.0066 - prc: 0.6023 - precision: 0.8079 - recall: 0.5776 - val_auc: 0.9311 - val_loss: 0.0103 - val_prc: 0.7423 - val_precision: 0.8272 - val_recall: 0.8375
# Epoch 6/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.8949 - loss: 0.0072 - prc: 0.5863 - precision: 0.7179 - recall: 0.5787 - val_auc: 0.9373 - val_loss: 0.0061 - val_prc: 0.7526 - val_precision: 0.8182 - val_recall: 0.6750
# Epoch 7/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9080 - loss: 0.0054 - prc: 0.6862 - precision: 0.8557 - recall: 0.6243 - val_auc: 0.9497 - val_loss: 0.0048 - val_prc: 0.7456 - val_precision: 0.8689 - val_recall: 0.6625
# Epoch 8/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9239 - loss: 0.0052 - prc: 0.6741 - precision: 0.8115 - recall: 0.6233 - val_auc: 0.9678 - val_loss: 0.0091 - val_prc: 0.7739 - val_precision: 0.7865 - val_recall: 0.8750
# Epoch 9/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9022 - loss: 0.0055 - prc: 0.6157 - precision: 0.7574 - recall: 0.5911 - val_auc: 0.9487 - val_loss: 0.0083 - val_prc: 0.7581 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 10/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9233 - loss: 0.0051 - prc: 0.6658 - precision: 0.8179 - recall: 0.6086 - val_auc: 0.9554 - val_loss: 0.0086 - val_prc: 0.7383 - val_precision: 0.7609 - val_recall: 0.8750
# Epoch 11/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9130 - loss: 0.0050 - prc: 0.6326 - precision: 0.8303 - recall: 0.6129 - val_auc: 0.9432 - val_loss: 0.0079 - val_prc: 0.7573 - val_precision: 0.8140 - val_recall: 0.8750
# Epoch 12/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9230 - loss: 0.0047 - prc: 0.7149 - precision: 0.8088 - recall: 0.6540 - val_auc: 0.9492 - val_loss: 0.0087 - val_prc: 0.7581 - val_precision: 0.7368 - val_recall: 0.8750
# Epoch 13/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9482 - loss: 0.0042 - prc: 0.7052 - precision: 0.8525 - recall: 0.6946 - val_auc: 0.9435 - val_loss: 0.0101 - val_prc: 0.7540 - val_precision: 0.7882 - val_recall: 0.8375
# Epoch 14/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9199 - loss: 0.0040 - prc: 0.6866 - precision: 0.8368 - recall: 0.6849 - val_auc: 0.9828 - val_loss: 0.0256 - val_prc: 0.6363 - val_precision: 0.2628 - val_recall: 0.9000
# Epoch 15/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9134 - loss: 0.0046 - prc: 0.6789 - precision: 0.8420 - recall: 0.6543 - val_auc: 0.9373 - val_loss: 0.0060 - val_prc: 0.7452 - val_precision: 0.8667 - val_recall: 0.8125
# Epoch 16/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9464 - loss: 0.0036 - prc: 0.7574 - precision: 0.8509 - recall: 0.7255 - val_auc: 0.9844 - val_loss: 0.0105 - val_prc: 0.7568 - val_precision: 0.7188 - val_recall: 0.8625
# Epoch 17/45
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.9269 - loss: 0.0043 - prc: 0.7026 - precision: 0.8675 - recall: 0.6657 - val_auc: 0.9494 - val_loss: 0.0077 - val_prc: 0.7594 - val_precision: 0.7865 - val_recall: 0.8750
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - auc: 0.9272 - loss: 0.0050 - prc: 0.7903 - precision: 0.9273 - recall: 0.5971

# %% [markdown]
# ### Create a Biased Model
#
# The bias of the data is inserted in the model compilation step on the output layer. What does this do? It preconfigures the output layer to "expect" results to be this skewed. Recall that, along with the weight, the bias values are one of the things that is learned in training. By default the initial values are randomized, so the model needs to learn the skew towards the imbalance - if the balance between classes is moderate, that's not a big deal; if the balance is so drastically skewed in one direction, that's less practical. With the preset bias we can speed convergance and likely reduce loss.
#
# #### Other Imbalenced Work
#
# Other things that we looked at to improve balance such as under/over sampling still works with neural networks as it would with anything else. This is just one nn-specific thing that we can implement with minimal extra work.
#
# #### Metrics
#
# We can also add a bunch of metrics to what we get returned by creating a list of the metrics that we want. Keras.metrics has a list, they are all the metrics we might expect.

# %%
initial_bias = np.log([pos/neg])

output_bias = tf.keras.initializers.Constant(initial_bias)
model = keras.Sequential()
model.add(InputLayer(shape=(train_features.shape[1],)))
model.add(BatchNormalization())
model.add(Dense(fraud_width_1, activation='leaky_relu', kernel_regularizer="l2"))
model.add(BatchNormalization())
model.add(Dense(fraud_width_1, activation='leaky_relu', kernel_regularizer="l2"))
model.add(BatchNormalization())
model.add(Dense(fraud_width_3, activation='leaky_relu', kernel_regularizer="l2"))
model.add(BatchNormalization())
model.add(Dense(1, activation='sigmoid', bias_initializer=output_bias))
model.summary()



#model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=metrics)
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=METRICS)
#Fit
train_log = model.fit(
  train_features,
  train_labels,
  epochs=SMALL_EPOCHS*5,
  batch_size=MID_BATCH,
  validation_split=0.2,
  callbacks=[callback]
)
model.evaluate(test_features, test_labels)
plot_loss(train_log)
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization_13               │ (None, 29)                  │             116 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_38 (Dense)                     │ (None, 16)                  │             480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_39 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_40 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_16               │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_41 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,349 (5.27 KB)
#  Trainable params: 1,195 (4.67 KB)
#  Non-trainable params: 154 (616.00 B)
# Epoch 1/75
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - auc: 0.9231 - loss: 0.0942 - prc: 0.6846 - precision: 0.8698 - recall: 0.5672 - val_auc: 0.9675 - val_loss: 0.0099 - val_prc: 0.7845 - val_precision: 0.7955 - val_recall: 0.8750
# Epoch 2/75
# 2849/2849 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - auc: 0.
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - auc: 0.9215 - loss: 0.0051 - prc: 0.7865 - precision: 0.9276 - recall: 0.6305

# %% [markdown]
# ### Model Structure and Tuning
#
# We'll look at tuning neural network models in more depth soon. For now, we can use the results of our model's training and validation scores, along with a few guidelines, to aim us in the correct direction for making a good model.
#
# Some guidelines for tuning neural networks are:
# <ul>
# <li> Start with something small-ish, and increase as needed. For our exercises, this likely means 2 or 3 hidden layers to start. </li>
# <li> Use early stopping to find the optimal number of epochs. </li>
# <li> If the training score is similar to the validation score, the model is probably underfitting. Try things to allow it to learn more:</li>
#     <ul>
#     <li> Increasing the number of layers. </li>
#     <li> Increasing the number of neurons in each layer. </li>
#     <li> Training for more epochs. </li>
#     </ul>
# <li> If the training score is much higher than the validation score, the model is probably overfitting. Try things to prevent it from learning too much:</li>
#     <ul>
#     <li> Adding regularization. </li>
#     <li> Adding dropout. </li>
#     <li> Reducing the number of layers or the size of the layers. </li>
#     </ul>
# <li> If the model's scores seem to flatline, try adding some batch normalization or changing some other optimization-ish option. </li>
# </ul>
#
# These are just guidelines, but they are a good starting point.

# %% [markdown]
# ## Exercise
#
# Predict the price of diamonds! (The example solutions are fairly extreme in terms of the approach they take, you'll probably be ok with less dramatic approaches.)
#
# ![Diamonds](images/diamonds.jpeg "Diamonds" )

# %%
ex_df = sns.load_dataset("diamonds")
ex_df = pd.get_dummies(ex_df)

ex_df.head()
# Out:
#    carat  depth  table  price     x     y     z  cut_Ideal  cut_Premium  \
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43       True        False
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31      False         True
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31      False        False
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63      False         True
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75      False        False
#
#    cut_Very Good  ...  color_I  color_J  clarity_IF  clarity_VVS1  \
# 0          False  ...    False    False       False         False
# 1          False  ...    False    False       False         False
# 2          False  ...    False    False       False         False
# 3          False  ...     True    False       False         False
# 4          False  ...    False     True       False         False
#
#    clarity_VVS2  clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  \
# 0         False        False        False        False         True
# 1         False        False        False         True        False
# 2         False         True        False        False        False
# 3         False        False         True        False        False
# 4         False        False        False        False         True
#
#    clarity_I1
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#
# [5 rows x 27 columns]

# %%
y = np.array(ex_df["price"]).astype(np.float32)
X = np.array(ex_df.drop(columns={"price"})).astype(np.float32)
X_tr_ex, X_te_ex, y_tr_ex, y_te_ex = train_test_split(X, y)
start_width = X.shape[1]
start_width
# Out:
# 26

# %%
ex_df.describe(include="all").T
# Out:
#                  count unique    top   freq         mean          std    min  \
# carat          53940.0    NaN    NaN    NaN      0.79794     0.474011    0.2
# depth          53940.0    NaN    NaN    NaN    61.749405     1.432621   43.0
# table          53940.0    NaN    NaN    NaN    57.457184     2.234491   43.0
# price          53940.0    NaN    NaN    NaN  3932.799722  3989.439738  326.0
# x              53940.0    NaN    NaN    NaN     5.731157     1.121761    0.0
# y              53940.0    NaN    NaN    NaN     5.734526     1.142135    0.0
# z              53940.0    NaN    NaN    NaN     3.538734     0.705699    0.0
# cut_Ideal        53940      2  False  32389          NaN          NaN    NaN
# cut_Premium      53940      2  False  40149          NaN          NaN    NaN
# cut_Very Good    53940      2  False  41858          NaN          NaN    NaN
# cut_Good         53940      2  False  49034          NaN          NaN    NaN
# cut_Fair         53940      2  False  52330          NaN          NaN    NaN
# color_D          53940      2  False  47165          NaN          NaN    NaN
# color_E          53940      2  False  44143          NaN          NaN    NaN
# color_F          53940      2  False  44398          NaN          NaN    NaN
# color_G          53940      2  False  42648          NaN          NaN    NaN
# color_H          53940      2  False  45636          NaN          NaN    NaN
# color_I          53940      2  False  48518          NaN          NaN    NaN
# color_J          53940      2  False  51132          NaN          NaN    NaN
# clarity_IF       53940      2  False  52150          NaN          NaN    NaN
# clarity_VVS1     53940      2  False  50285          NaN          NaN    NaN
# clarity_VVS2     53940      2  False  48874          NaN          NaN    NaN
# clarity_VS1      53940      2  False  45769          NaN          NaN    NaN
# clarity_VS2      53940      2  False  41682          NaN          NaN    NaN
# clarity_SI1      53940      2  False  40875          NaN          NaN    NaN
# clarity_SI2      53940      2  False  44746          NaN          NaN    NaN
# clarity_I1       53940      2  False  53199          NaN          NaN    NaN
#
#                  25%     50%      75%      max
# carat            0.4     0.7     1.04     5.01
# depth           61.0    61.8     62.5     79.0
# table           56.0    57.0     59.0     95.0
# price          950.0  2401.0  5324.25  18823.0
# x               4.71     5.7     6.54    10.74
# y               4.72    5.71     6.54     58.9
# z               2.91    3.53     4.04     31.8
# cut_Ideal        NaN     NaN      NaN      NaN
# cut_Premium      NaN     NaN      NaN      NaN
# cut_Very Good    NaN     NaN      NaN      NaN
# cut_Good         NaN     NaN      NaN      NaN
# cut_Fair         NaN     NaN      NaN      NaN
# color_D          NaN     NaN      NaN      NaN
# color_E          NaN     NaN      NaN      NaN
# color_F          NaN     NaN      NaN      NaN
# color_G          NaN     NaN      NaN      NaN
# color_H          NaN     NaN      NaN      NaN
# color_I          NaN     NaN      NaN      NaN
# color_J          NaN     NaN      NaN      NaN
# clarity_IF       NaN     NaN      NaN      NaN
# clarity_VVS1     NaN     NaN      NaN      NaN
# clarity_VVS2     NaN     NaN      NaN      NaN
# clarity_VS1      NaN     NaN      NaN      NaN
# clarity_VS2      NaN     NaN      NaN      NaN
# clarity_SI1      NaN     NaN      NaN      NaN
# clarity_SI2      NaN     NaN      NaN      NaN
# clarity_I1       NaN     NaN      NaN      NaN

# %% [markdown]
# #### Generate a Baseline
#
# I'll use a different loss - mean absolute percentage.

# %%
#baseline

mod_ex = keras.Sequential()
mod_ex.add(InputLayer(shape=(start_width,)))
model.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(1))

mod_ex.compile(optimizer='adam', loss="mean_absolute_percentage_error")

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

hist_ex = mod_ex.fit(
  X_tr_ex,
  y_tr_ex,
  epochs=LARGE_EPOCHS,
  batch_size=MID_BATCH,
  validation_split=0.2,
  callbacks=[callback],
  verbose=0
)
print(mod_ex.evaluate(X_te_ex, y_te_ex))
plot_loss(hist_ex)
# Out:
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.5728
# 10.468998908996582

# %% [markdown]
# ### Attempt Optimization
#
# Looks like lots of loss! What to do?
#
# Things to try:
# <ol>
# <li> Depth.
# <li> Width.
# <li> Activations.
# <li> Batches.
# </ol>

# %%
#Comically Deep Model

mod_ex = keras.Sequential()
mod_ex.add(InputLayer(shape=(start_width,)))
model.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(1))

mod_ex.compile(optimizer='adam', loss="mean_absolute_percentage_error")

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

hist_ex = mod_ex.fit(
  X_tr_ex,
  y_tr_ex,
  epochs=LARGE_EPOCHS,
  batch_size=MID_BATCH,
  validation_split=0.2,
  callbacks=[callback],
  verbose=0
)
print(mod_ex.evaluate(X_te_ex, y_te_ex))
plot_loss(hist_ex)
# Out:
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.7410
# 8.520276069641113

# %% [markdown]
# ##### Try Adding Dropouts
#
# We don't have a bunch of overfitting, so we may not expect miracles here...

# %%
#Comically Deep Model with Dropouts

mod_ex = keras.Sequential()
mod_ex.add(InputLayer(shape=(start_width,)))
model.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dropout(.2))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(1))

mod_ex.compile(optimizer='adam', loss="mean_absolute_percentage_error")

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

hist_ex = mod_ex.fit(
  X_tr_ex,
  y_tr_ex,
  epochs=LARGE_EPOCHS,
  batch_size=XL_BATCH,
  validation_split=0.2,
  callbacks=[callback],
  verbose=0
)
print(mod_ex.evaluate(X_te_ex, y_te_ex))
plot_loss(hist_ex)
# Out:
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 59.0270
# 59.520286560058594

# %% [markdown]
# ##### Taper Model Somewhat

# %%
#Taper Deep Model
half_width = int(np.floor(start_width/2))
third_width = int(np.floor(start_width/3))
mod_ex = keras.Sequential()
mod_ex.add(InputLayer(shape=(start_width,)))
model.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(start_width, activation='relu'))
mod_ex.add(Dense(half_width, activation='relu'))
mod_ex.add(Dense(half_width, activation='relu'))
mod_ex.add(Dense(third_width, activation='relu'))
mod_ex.add(Dense(third_width, activation='relu'))
mod_ex.add(Dense(1))

mod_ex.compile(optimizer='adam', loss="mean_absolute_percentage_error", metrics=[metrics.mean_squared_error,
                                                                        metrics.mean_absolute_error,
                                                                        metrics.mean_absolute_percentage_error])

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

hist_ex = mod_ex.fit(
  X_tr_ex,
  y_tr_ex,
  epochs=LARGE_EPOCHS,
  batch_size=MID_BATCH,
  validation_split=0.2,
  callbacks=[callback],
  verbose=1
)
print(mod_ex.evaluate(X_te_ex, y_te_ex))
plot_loss(hist_ex)
# Out:
# Epoch 1/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 73.3188 - mean_absolute_error: 3417.8523 - mean_absolute_percentage_error: 73.3188 - mean_squared_error: 27455606.0000 - val_loss: 58.5919 - val_mean_absolute_error: 3155.4500 - val_mean_absolute_percentage_error: 58.5919 - val_mean_squared_error: 25376608.0000
# Epoch 2/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 58.1932 - mean_absolute_error: 3111.0068 - mean_absolute_percentage_error: 58.1932 - mean_squared_error: 24746414.0000 - val_loss: 47.5697 - val_mean_absolute_error: 2738.4490 - val_mean_absolute_percentage_error: 47.5697 - val_mean_squared_error: 20308262.0000
# Epoch 3/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27.2730 - mean_absolute_error: 1483.1757 - mean_absolute_percentage_error: 27.2730 - mean_squared_error: 8446834.0000 - val_loss: 13.2268 - val_mean_absolute_error: 633.5997 - val_mean_absolute_percentage_error: 13.2268 - val_mean_squared_error: 1580303.3750
# Epoch 4/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.7012 - mean_absolute_error: 559.2067 - mean_absolute_percentage_error: 12.7012 - mean_squared_error: 1340978.8750 - val_loss: 11.5985 - val_mean_absolute_error: 503.2134 - val_mean_absolute_percentage_error: 11.5985 - val_mean_squared_error: 1012583.5000
# Epoch 5/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.0102 - mean_absolute_error: 516.9207 - mean_absolute_percentage_error: 12.0102 - mean_squared_error: 1303186.3750 - val_loss: 11.5299 - val_mean_absolute_error: 489.9708 - val_mean_absolute_percentage_error: 11.5299 - val_mean_squared_error: 925344.2500
# Epoch 6/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.3420 - mean_absolute_error: 472.6314 - mean_absolute_percentage_error: 11.3420 - mean_squared_error: 883119.5625 - val_loss: 11.3705 - val_mean_absolute_error: 447.0175 - val_mean_absolute_percentage_error: 11.3705 - val_mean_squared_error: 759730.5625
# Epoch 7/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.1093 - mean_absolute_error: 448.5560 - mean_absolute_percentage_error: 11.1093 - mean_squared_error: 765373.2500 - val_loss: 10.8310 - val_mean_absolute_error: 436.2334 - val_mean_absolute_percentage_error: 10.8310 - val_mean_squared_error: 707320.1250
# Epoch 8/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.8900 - mean_absolute_error: 423.9030 - mean_absolute_percentage_error: 10.8900 - mean_squared_error: 711764.5625 - val_loss: 11.6180 - val_mean_absolute_error: 486.3195 - val_mean_absolute_percentage_error: 11.6180 - val_mean_squared_error: 830348.2500
# Epoch 9/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.9055 - mean_absolute_error: 424.3317 - mean_absolute_percentage_error: 10.9055 - mean_squared_error: 705269.0625 - val_loss: 10.8473 - val_mean_absolute_error: 406.8095 - val_mean_absolute_percentage_error: 10.8473 - val_mean_squared_error: 614625.6250
# Epoch 10/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.6304 - mean_absolute_error: 415.8675 - mean_absolute_percentage_error: 10.6304 - mean_squared_error: 727720.8750 - val_loss: 10.2234 - val_mean_absolute_error: 410.3267 - val_mean_absolute_percentage_error: 10.2234 - val_mean_squared_error: 615016.1875
# Epoch 11/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.2683 - mean_absolute_error: 398.0598 - mean_absolute_percentage_error: 10.2683 - mean_squared_error: 761466.2500 - val_loss: 10.5373 - val_mean_absolute_error: 391.7690 - val_mean_absolute_percentage_error: 10.5373 - val_mean_squared_error: 564426.5000
# Epoch 12/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.4055 - mean_absolute_error: 401.0809 - mean_absolute_percentage_error: 10.4055 - mean_squared_error: 659711.5000 - val_loss: 10.0728 - val_mean_absolute_error: 407.2635 - val_mean_absolute_percentage_error: 10.0728 - val_mean_squared_error: 607063.9375
# Epoch 13/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.2443 - mean_absolute_error: 394.2074 - mean_absolute_percentage_error: 10.2443 - mean_squared_error: 675626.6250 - val_loss: 10.3214 - val_mean_absolute_error: 440.3355 - val_mean_absolute_percentage_error: 10.3214 - val_mean_squared_error: 690292.5000
# Epoch 14/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.9625 - mean_absolute_error: 386.1062 - mean_absolute_percentage_error: 9.9625 - mean_squared_error: 600357.8125 - val_loss: 10.1554 - val_mean_absolute_error: 379.7894 - val_mean_absolute_percentage_error: 10.1554 - val_mean_squared_error: 532155.3750
# Epoch 15/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss:
200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.8036 - mean_absolute_error: 327.6973 - mean_absolute_percentage_error: 8.8036 - mean_squared_error: 373444.5625 - val_loss: 8.7493 - val_mean_absolute_error: 324.8883 - val_mean_absolute_percentage_error: 8.7493 - val_mean_squared_error: 413885.9062
# Epoch 50/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.7761 - mean_absolute_error: 327.8451 - mean_absolute_percentage_error: 8.7761 - mean_squared_error: 421217.5938 - val_loss: 10.1807 - val_mean_absolute_error: 354.6399 - val_mean_absolute_percentage_error: 10.1807 - val_mean_squared_error: 459373.2812
# Epoch 51/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.8125 - mean_absolute_error: 330.0536 - mean_absolute_percentage_error: 8.8125 - mean_squared_error: 437605.1562 - val_loss: 9.3450 - val_mean_absolute_error: 347.3151 - val_mean_absolute_percentage_error: 9.3450 - val_mean_squared_error: 471224.7188
# Epoch 52/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.8604 - mean_absolute_error: 327.7166 - mean_absolute_percentage_error: 8.8604 - mean_squared_error: 410047.1562 - val_loss: 8.6770 - val_mean_absolute_error: 329.2813 - val_mean_absolute_percentage_error: 8.6770 - val_mean_squared_error: 436275.2500
# Epoch 53/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.7375 - mean_absolute_error: 318.8504 - mean_absolute_percentage_error: 8.7375 - mean_squared_error: 365395.3750 - val_loss: 8.6726 - val_mean_absolute_error: 327.3470 - val_mean_absolute_percentage_error: 8.6726 - val_mean_squared_error: 412931.5312
# Epoch 54/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.7564 - mean_absolute_error: 326.0568 - mean_absolute_percentage_error: 8.7564 - mean_squared_error: 407103.6875 - val_loss: 8.5287 - val_mean_absolute_error: 330.1045 - val_mean_absolute_percentage_error: 8.5287 - val_mean_squared_error: 419950.1875
# Epoch 55/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.7012 - mean_absolute_error: 323.0065 - mean_absolute_percentage_error: 8.7012 - mean_squared_error: 369750.3125 - val_loss: 8.6109 - val_mean_absolute_error: 324.0882 - val_mean_absolute_percentage_error: 8.6109 - val_mean_squared_error: 421739.8125
# Epoch 56/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.7071 - mean_absolute_error: 324.1857 - mean_absolute_percentage_error: 8.7071 - mean_squared_error: 387266.5312 - val_loss: 8.5535 - val_mean_absolute_error: 339.3507 - val_mean_absolute_percentage_error: 8.5535 - val_mean_squared_error: 433314.5938
# Epoch 57/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.7171 - mean_absolute_error: 323.4416 - mean_absolute_percentage_error: 8.7171 - mean_squared_error: 414309.9688 - val_loss: 8.5455 - val_mean_absolute_error: 326.7961 - val_mean_absolute_percentage_error: 8.5455 - val_mean_squared_error: 414673.1250
# Epoch 58/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.6156 - mean_absolute_error: 318.8167 - mean_absolute_percentage_error: 8.6156 - mean_squared_error: 373016.9375 - val_loss: 8.5544 - val_mean_absolute_error: 336.1531 - val_mean_absolute_percentage_error: 8.5544 - val_mean_squared_error: 425686.8750
# Epoch 59/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.7398 - mean_absolute_error: 325.1804 - mean_absolute_percentage_error: 8.7398 - mean_squared_error: 390937.6875 - val_loss: 9.0127 - val_mean_absolute_error: 364.8382 - val_mean_absolute_percentage_error: 9.0127 - val_mean_squared_error: 473934.5000
# Epoch 60/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.6968 - mean_absolute_error: 322.2615 - mean_absolute_percentage_error: 8.6968 - mean_squared_error: 382001.0938 - val_loss: 8.6692 - val_mean_absolute_error: 340.1235 - val_mean_absolute_percentage_error: 8.6692 - val_mean_squared_error: 429833.8750
# Epoch 61/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.6258 - mean_absolute_error: 314.9756 - mean_absolute_percentage_error: 8.6258 - mean_squared_error: 357020.2812 - val_loss: 8.4171 - val_mean_absolute_error: 326.3356 - val_mean_absolute_percentage_error: 8.4171 - val_mean_squared_error: 412917.0625
# Epoch 62/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.5928 - mean_absolute_error: 322.0908 - mean_absolute_percentage_error: 8.5928 - mean_squared_error: 391781.1875 - val_loss: 8.3920 - val_mean_absolute_error: 327.1676 - val_mean_absolute_percentage_error: 8.3920 - val_mean_squared_error: 412280.0938
# Epoch 63/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.6701 - mean_absolute_error: 324.6043 - mean_absolute_percentage_error: 8.6701 - mean_squared_error: 395404.2812 - val_loss: 8.6174 - val_mean_absolute_error: 342.5729 - val_mean_absolute_percentage_error: 8.6174 - val_mean_squared_error: 431317.7500
# Epoch 64/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.5551 - mean_absolute_error: 316.8609 - mean_absolute_percentage_error: 8.5551 - mean_squared_error: 359018.2500 - val_loss: 8.5658 - val_mean_absolute_error: 319.1356 - val_mean_absolute_percentage_error: 8.5658 - val_mean_squared_error: 408659.1562
# Epoch 65/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.4502 - mean_absolute_error: 314.8173 - mean_absolute_percentage_error: 8.4502 - mean_squared_error: 357749.5625 - val_loss: 8.2824 - val_mean_absolute_error: 321.8951 - val_mean_absolute_percentage_error: 8.2824 - val_mean_squared_error: 406721.0625
# Epoch 66/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.5458 - mean_absolute_error: 319.4360 - mean_absolute_percentage_error: 8.5458 - mean_squared_error: 385128.6250 - val_loss: 8.5705 - val_mean_absolute_error: 344.5228 - val_mean_absolute_percentage_error: 8.5705 - val_mean_squared_error: 450270.9062
# Epoch 67/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.4607 - mean_absolute_error: 316.7695 - mean_absolute_percentage_error: 8.4607 - mean_squared_error: 371029.2500 - val_loss: 8.3368 - val_mean_absolute_error: 323.8397 - val_mean_absolute_percentage_error: 8.3368 - val_mean_squared_error: 413957.5938
# Epoch 68/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3866 - mean_absolute_error: 311.0402 - mean_absolute_percentage_error: 8.3866 - mean_squared_error: 353012.5000 - val_loss: 8.4049 - val_mean_absolute_error: 323.7541 - val_mean_absolute_percentage_error: 8.4049 - val_mean_squared_error: 410153.1250
# Epoch 69/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.5045 - mean_absolute_error: 317.9550 - mean_absolute_percentage_error: 8.5045 - mean_squared_error: 380982.9688 - val_loss: 8.3483 - val_mean_absolute_error: 319.9315 - val_mean_absolute_percentage_error: 8.3483 - val_mean_squared_error: 411877.1875
# Epoch 70/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.5291 - mean_absolute_error: 319.8221 - mean_absolute_percentage_error: 8.5291 - mean_squared_error: 387961.9375 - val_loss: 8.2512 - val_mean_absolute_error: 324.9534 - val_mean_absolute_percentage_error: 8.2512 - val_mean_squared_error: 413028.7500
# Epoch 71/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.5422 - mean_absolute_error: 317.4236 - mean_absolute_percentage_error: 8.5422 - mean_squared_error: 382785.0938 - val_loss: 8.3385 - val_mean_absolute_error: 319.6953 - val_mean_absolute_percentage_error: 8.3385 - val_mean_squared_error: 422041.7188
# Epoch 72/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3006 - mean_absolute_error: 311.5977 - mean_absolute_percentage_error: 8.3006 - mean_squared_error: 359561.5000 - val_loss: 8.2956 - val_mean_absolute_error: 319.4173 - val_mean_absolute_percentage_error: 8.2956 - val_mean_squared_error: 406029.2812
# Epoch 73/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.5656 - mean_absolute_error: 320.1142 - mean_absolute_percentage_error: 8.5656 - mean_squared_error: 376206.4062 - val_loss: 8.6080 - val_mean_absolute_error: 318.5326 - val_mean_absolute_percentage_error: 8.6080 - val_mean_squared_error: 398592.7812
# Epoch 74/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.4286 - mean_absolute_error: 315.3163 - mean_absolute_percentage_error: 8.4286 - mean_squared_error: 373233.9688 - val_loss: 8.3510 - val_mean_absolute_error: 323.5132 - val_mean_absolute_percentage_error: 8.3510 - val_mean_squared_error: 416351.4375
# Epoch 75/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.4168 - mean_absolute_error: 313.5497 - mean_absolute_percentage_error: 8.4168 - mean_squared_error: 371515.5625 - val_loss: 8.6719 - val_mean_absolute_error: 328.0602 - val_mean_absolute_percentage_error: 8.6719 - val_mean_squared_error: 406171.5000
# Epoch 76/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3617 - mean_absolute_error: 310.9150 - mean_absolute_percentage_error: 8.3617 - mean_squared_error: 364798.9062 - val_loss: 8.2129 - val_mean_absolute_error: 317.4505 - val_mean_absolute_percentage_error: 8.2129 - val_mean_squared_error: 423532.5625
# Epoch 77/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3314 - mean_absolute_error: 306.2215 - mean_absolute_percentage_error: 8.3314 - mean_squared_error: 358267.0312 - val_loss: 8.1861 - val_mean_absolute_error: 318.1146 - val_mean_absolute_percentage_error: 8.1861 - val_mean_squared_error: 398026.4062
# Epoch 78/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3824 - mean_absolute_error: 312.3009 - mean_absolute_percentage_error: 8.3824 - mean_squared_error: 354421.1562 - val_loss: 8.1827 - val_mean_absolute_error: 317.5250 - val_mean_absolute_percentage_error: 8.1827 - val_mean_squared_error: 414021.1250
# Epoch 79/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3119 - mean_absolute_error: 310.8196 - mean_absolute_percentage_error: 8.3119 - mean_squared_error: 359912.7188 - val_loss: 8.3458 - val_mean_absolute_error: 332.0620 - val_mean_absolute_percentage_error: 8.3458 - val_mean_squared_error: 426058.2188
# Epoch 80/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3519 - mean_absolute_error: 311.8968 - mean_absolute_percentage_error: 8.3519 - mean_squared_error: 371721.5000 - val_loss: 8.4086 - val_mean_absolute_error: 328.9345 - val_mean_absolute_percentage_error: 8.4086 - val_mean_squared_error: 420215.7500
# Epoch 81/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2853 - mean_absolute_error: 310.8271 - mean_absolute_percentage_error: 8.2853 - mean_squared_error: 367659.6875 - val_loss: 8.3054 - val_mean_absolute_error: 316.3000 - val_mean_absolute_percentage_error: 8.3054 - val_mean_squared_error: 411645.2188
# Epoch 82/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2939 - mean_absolute_error: 313.1569 - mean_absolute_percentage_error: 8.2939 - mean_squared_error: 359492.0938 - val_loss: 8.3866 - val_mean_absolute_error: 322.1322 - val_mean_absolute_percentage_error: 8.3866 - val_mean_squared_error: 408072.0000
# Epoch 83/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3187 - mean_absolute_error: 310.4581 - mean_absolute_percentage_error: 8.3187 - mean_squared_error: 350865.8125 - val_loss: 8.4925 - val_mean_absolute_error: 346.3348 - val_mean_absolute_percentage_error: 8.4925 - val_mean_squared_error: 439523.0938
# Epoch 84/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2792 - mean_absolute_error: 316.7368 - mean_absolute_percentage_error: 8.2792 - mean_squared_error: 376777.9688 - val_loss: 8.2581 - val_mean_absolute_error: 316.1812 - val_mean_absolute_percentage_error: 8.2581 - val_mean_squared_error: 412941.0000
# Epoch 85/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2238 - mean_absolute_error: 310.3557 - mean_absolute_percentage_error: 8.2238 - mean_squared_error: 377338.2188 - val_loss: 8.5175 - val_mean_absolute_error: 319.1529 - val_mean_absolute_percentage_error: 8.5175 - val_mean_squared_error: 429243.3438
# Epoch 86/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3724 - mean_absolute_error: 312.5202 - mean_absolute_percentage_error: 8.3724 - mean_squared_error: 375685.9062 - val_loss: 8.0615 - val_mean_absolute_error: 315.3843 - val_mean_absolute_percentage_error: 8.0615 - val_mean_squared_error: 397337.4375
# Epoch 87/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3283 - mean_absolute_error: 311.8709 - mean_absolute_percentage_error: 8.3283 - mean_squared_error: 371801.7188 - val_loss: 8.5883 - val_mean_absolute_error: 340.5816 - val_mean_absolute_percentage_error: 8.5883 - val_mean_squared_error: 422247.2188
# Epoch 88/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3132 - mean_absolute_error: 316.1545 - mean_absolute_percentage_error: 8.3132 - mean_squared_error: 378119.1562 - val_loss: 8.1537 - val_mean_absolute_error: 317.8357 - val_mean_absolute_percentage_error: 8.1537 - val_mean_squared_error: 398559.4688
# Epoch 89/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2149 - mean_absolute_error: 306.1976 - mean_absolute_percentage_error: 8.2149 - mean_squared_error: 350117.8125 - val_loss: 8.6660 - val_mean_absolute_error: 332.2770 - val_mean_absolute_percentage_error: 8.6660 - val_mean_squared_error: 413276.5938
# Epoch 90/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2636 - mean_absolute_error: 308.2474 - mean_absolute_percentage_error: 8.2636 - mean_squared_error: 366063.6875 - val_loss: 8.1264 - val_mean_absolute_error: 312.0250 - val_mean_absolute_percentage_error: 8.1264 - val_mean_squared_error: 396416.7500
# Epoch 91/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2847 - mean_absolute_error: 312.7277 - mean_absolute_percentage_error: 8.2847 - mean_squared_error: 375219.7500 - val_loss: 8.5774 - val_mean_absolute_error: 338.8089 - val_mean_absolute_percentage_error: 8.5774 - val_mean_squared_error: 424140.2812
# Epoch 92/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.0994 - mean_absolute_error: 301.9703 - mean_absolute_percentage_error: 8.0994 - mean_squared_error: 359595.7188 - val_loss: 8.1196 - val_mean_absolute_error: 317.5923 - val_mean_absolute_percentage_error: 8.1196 - val_mean_squared_error: 406158.9062
# Epoch 93/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1396 - mean_absolute_error: 304.8507 - mean_absolute_percentage_error: 8.1396 - mean_squared_error: 359159.3125 - val_loss: 8.1455 - val_mean_absolute_error: 320.9004 - val_mean_absolute_percentage_error: 8.1455 - val_mean_squared_error: 400639.7500
# Epoch 94/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2040 - mean_absolute_error: 304.4463 - mean_absolute_percentage_error: 8.2040 - mean_squared_error: 351111.0312 - val_loss: 8.2264 - val_mean_absolute_error: 310.3558 - val_mean_absolute_percentage_error: 8.2264 - val_mean_squared_error: 404866.4688
# Epoch 95/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2569 - mean_absolute_error: 308.0412 - mean_absolute_percentage_error: 8.2569 - mean_squared_error: 362001.1875 - val_loss: 8.0439 - val_mean_absolute_error: 310.7211 - val_mean_absolute_percentage_error: 8.0439 - val_mean_squared_error: 404285.6562
# Epoch 96/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2430 - mean_absolute_error: 306.7870 - mean_absolute_percentage_error: 8.2430 - mean_squared_error: 356917.1875 - val_loss: 8.0619 - val_mean_absolute_error: 313.2581 - val_mean_absolute_percentage_error: 8.0619 - val_mean_squared_error: 410365.2500
# Epoch 97/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2380 - mean_absolute_error: 307.5120 - mean_absolute_percentage_error: 8.2380 - mean_squared_error: 385217.8125 - val_loss: 7.9959 - val_mean_absolute_error: 309.8234 - val_mean_absolute_percentage_error: 7.9959 - val_mean_squared_error: 397110.2812
# Epoch 98/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1287 - mean_absolute_error: 307.4716 - mean_absolute_percentage_error: 8.1287 - mean_squared_error: 357360.9062 - val_loss: 8.1914 - val_mean_absolute_error: 317.3589 - val_mean_absolute_percentage_error: 8.1914 - val_mean_squared_error: 435734.8438
# Epoch 99/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2171 - mean_absolute_error: 305.4150 - mean_absolute_percentage_error: 8.2171 - mean_squared_error: 351194.4375 - val_loss: 8.1096 - val_mean_absolute_error: 311.9989 - val_mean_absolute_percentage_error: 8.1096 - val_mean_squared_error: 400647.9062
# Epoch 100/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.0765 - mean_absolute_error: 298.3669 - mean_absolute_percentage_error: 8.0765 - mean_squared_error: 339073.1562 - val_loss: 8.6479 - val_mean_absolute_error: 313.4833 - val_mean_absolute_percentage_error: 8.6479 - val_mean_squared_error: 404825.2812
# Epoch 101/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1985 - mean_absolute_error: 302.8990 - mean_absolute_percentage_error: 8.1985 - mean_squared_error: 349523.6562 - val_loss: 7.9609 - val_mean_absolute_error: 309.9143 - val_mean_absolute_percentage_error: 7.9609 - val_mean_squared_error: 399055.0938
# Epoch 102/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2377 - mean_absolute_error: 302.9895 - mean_absolute_percentage_error: 8.2377 - mean_squared_error: 350570.3750 - val_loss: 8.1845 - val_mean_absolute_error: 310.3153 - val_mean_absolute_percentage_error: 8.1845 - val_mean_squared_error: 397813.7812
# Epoch 103/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.0773 - mean_absolute_error: 300.6383 - mean_absolute_percentage_error: 8.0773 - mean_squared_error: 339171.4375 - val_loss: 8.0073 - val_mean_absolute_error: 311.7858 - val_mean_absolute_percentage_error: 8.0073 - val_mean_squared_error: 399856.0000
# Epoch 104/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1636 - mean_absolute_error: 303.8691 - mean_absolute_percentage_error: 8.1636 - mean_squared_error: 339886.7188 - val_loss: 8.3171 - val_mean_absolute_error: 313.7828 - val_mean_absolute_percentage_error: 8.3171 - val_mean_squared_error: 430807.1250
# Epoch 105/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1770 - mean_absolute_error: 302.4856 - mean_absolute_percentage_error: 8.1770 - mean_squared_error: 347914.7812 - val_loss: 8.2829 - val_mean_absolute_error: 319.2918 - val_mean_absolute_percentage_error: 8.2829 - val_mean_squared_error: 400929.6562
# Epoch 106/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1443 - mean_absolute_error: 301.1705 - mean_absolute_percentage_error: 8.1443 - mean_squared_error: 347609.1875 - val_loss: 8.0734 - val_mean_absolute_error: 322.2086 - val_mean_absolute_percentage_error: 8.0734 - val_mean_squared_error: 406065.3750
# Epoch 107/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3158 - mean_absolute_error: 308.9167 - mean_absolute_percentage_error: 8.3158 - mean_squared_error: 355963.1562 - val_loss: 7.9829 - val_mean_absolute_error: 312.0110 - val_mean_absolute_percentage_error: 7.9829 - val_mean_squared_error: 397105.5312
# Epoch 108/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.0207 - mean_absolute_error: 295.6999 - mean_absolute_percentage_error: 8.0207 - mean_squared_error: 323855.9375 - val_loss: 8.0506 - val_mean_absolute_error: 314.4348 - val_mean_absolute_percentage_error: 8.0506 - val_mean_squared_error: 417335.3438
# Epoch 109/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1034 - mean_absolute_error: 298.5345 - mean_absolute_percentage_error: 8.1034 - mean_squared_error: 351361.2500 - val_loss: 8.2898 - val_mean_absolute_error: 338.6201 - val_mean_absolute_percentage_error: 8.2898 - val_mean_squared_error: 437935.1250
# Epoch 110/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1048 - mean_absolute_error: 302.0473 - mean_absolute_percentage_error: 8.1048 - mean_squared_error: 371137.4062 - val_loss: 8.4415 - val_mean_absolute_error: 322.8420 - val_mean_absolute_percentage_error: 8.4415 - val_mean_squared_error: 448076.3438
# Epoch 111/200
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.2267 - mean_absolute_error: 304.9356 - mean_absolute_percentage_error: 8.2267 - mean_squared_error: 353153.9688 - val_loss: 8.0229 - val_mean_absolute_error: 305.2712 - val_mean_absolute_percentage_error: 8.0229 - val_mean_squared_error: 392011.6562
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.3476 - mean_absolute_error: 302.3965 - mean_absolute_percentage_error: 8.3476 - mean_squared_error: 807428.6250
# [8.158442497253418, 607868.625, 301.98779296875, 8.158442497253418]

# %% [markdown]
# #### Best Trial
#
# This may vary a bit, but what I saw in the results above was broadly:
# <ul>
# <li> Train and test results improved by adding layers. </li>
# <li> Adding dropouts didn't help much. </li>
# <li> Batch normalization helped a bit. </li>
# <li> Tapering didn't help, though this varied a lot depending on trials. </li>
# </ul>
#
# I tried a combo of those things to see the results. In general, this seemed to work best with a larger model, lots of training, and some normalization to keep it learning. There may be other structures that work just as well, or better, but from my trials, these patterns emerged from the results. I made a model to mirror that:
# <ul>
# <li> Start with a wide layer. </li>
# <li> Have several layers (the model seemed to keep learning with more layers in previous trails)). </li>
# <li> Use regularization. </li>
# <li> Add batch normalization. (The loss flatlined previously). </li>
# <li> Allow for many epochs, until improvement stops. </li>
# </ul>

# %%
# Best Guess

mod_ex = keras.Sequential()
mod_ex.add(InputLayer(shape=(start_width,)))
model.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
mod_ex.add(Dense(start_width, activation='relu', kernel_regularizer="l2"))
mod_ex.add(BatchNormalization())
#mod_ex.add(Dense(half_width, activation='relu', kernel_regularizer="l2"))
#mod_ex.add(BatchNormalization())
#mod_ex.add(Dense(third_width, activation='relu', kernel_regularizer="l2"))
#mod_ex.add(BatchNormalization())
mod_ex.add(Dense(1))
mod_ex.compile(optimizer='adam', loss="mean_absolute_percentage_error")

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE*10, restore_best_weights=True)

hist_ex = mod_ex.fit(
  X_tr_ex,
  y_tr_ex,
  epochs=LARGE_EPOCHS*5,
  batch_size=SMALL_BATCH,
  validation_split=0.35,
  callbacks=[callback],
  verbose=1
)
print(mod_ex.evaluate(X_te_ex, y_te_ex))
plot_loss(hist_ex)
# Out:
# Epoch 1/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - loss: 88.6661 - val_loss: 66.3940
# Epoch 2/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 59.9117 - val_loss: 54.3701
# Epoch 3/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 50.5146 - val_loss: 43.4911
# Epoch 4/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 47.7552 - val_loss: 40.9061
# Epoch 5/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 47.4772 - val_loss: 49.8470
# Epoch 6/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 46.5177 - val_loss: 46.5920
# Epoch 7/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 46.0684 - val_loss: 36.5711
# Epoch 8/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 45.8349 - val_loss: 36.7072
# Epoch 9/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 45.5703 - val_loss: 32.1014
# Epoch 10/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 45.1509 - val_loss: 36.1363
# Epoch 11/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 45.3294 - val_loss: 39.0017
# Epoch 12/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 45.0917 - val_loss: 36.8612
# Epoch 13/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 44.3707 - val_loss: 41.6559
# Epoch 14/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 45.0679 - val_loss: 37.4978
# Epoch 15/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 45.0427 - val_loss: 34.3492
# Epoch 16/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 44.1224 - val_loss: 41.8685
# Epoch 17/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 44.0777 - val_loss: 47.0883
# Epoch 18/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 44.4534 - val_loss: 34.4737
# Epoch 19/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 43.9374 - val_loss: 46.4067
# Epoch 20/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 43.7244 - val_loss: 31.8346
# Epoch 21/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 43.4226 - val_loss: 32.8600
# Epoch 22/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 43.9495 - val_loss: 31.1137
# Epoch 23/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 43.3146 - val_loss: 44.9484
# Epoch 24/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 43.6770 - val_loss: 41.2510
# Epoch 25/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 44.1092 - val_loss: 29.9536
# Epoch 26/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 43.6214 - val_loss: 27.9055
# Epoch 27/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 43.5054 - val_loss: 34.7472
# Epoch 28/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 43.6072 - val_loss: 31.2030
# Epoch 29/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 42.9585 - val_loss: 31.8413
# Epoch 30/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 43.0154 - val_loss: 29.3962
# Epoch 31/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 42.3883 - val_loss: 37.9847
# Epoch 32/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 42.7873 - val_loss: 33.2630
# Epoch 33/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 42.5911 - val_loss: 30.7878
# Epoch 34/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 43.3600 - val_loss: 34.2991
# Epoch 35/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 42.7006 - val_loss: 31.6643
# Epoch 36/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 42.4900 - val_loss: 34.8615
# Epoch 37/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 42.4686 - val_loss: 31.6914
# Epoch 38/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 43.1455 - val_loss: 30.7484
# Epoch 39/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 43.0348 - val_loss: 31.3027
# Epoch 40/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 42.3571 - val_loss: 30.7804
# Epoch 41/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 42.3470 - val_loss: 40.2529
# Epoch 42/1000
# 6574/6574 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 42